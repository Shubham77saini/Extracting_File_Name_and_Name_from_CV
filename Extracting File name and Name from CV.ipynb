# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import TextConverter
from io import StringIO
from pdfminer.pdfpage import PDFPage
import PyPDF2

# %%
path_to_pdf = r"C:\Users\shubh\OneDrive\Documents\Assignment\abhinavsaxenaesade.gmail@naukri.comabhinavsaxenaesade@gmailDotcom.pdf"

# %%
def get_pdf_file_content(path_to_pdf):
    
    '''
    path_to_pdf: is the parameter that will give access to the PDF File 
    we want to extract the content.
    '''
    
    '''
    PDFResourceManager is used to store shared resources such as fonts or images that 
    we might encounter in the files. 
    '''
    
    resource_manager = PDFResourceManager(caching=True)
    
    '''
    create a string object that will contain the final text the representation of the pdf. 
    '''
    out_text = StringIO()
    
    '''
    UTF-8 is one of the most commonly used encodings, and Python often defaults to using it.
    In our case, we are going to specify in order to avoid some encoding errors.
    '''
    codec = 'utf-8'
    
    """
    LAParams is the object containing the Layout parameters with a certain default value. 
    """
    laParams = LAParams()
    
    '''
    Create a TextConverter Object, taking :
    - ressource_manager,
    - out_text 
    - layout parameters.
    '''
    text_converter = TextConverter(resource_manager, out_text, laparams=laParams)
    fp = open(path_to_pdf, 'rb')
    
    '''
    Create a PDF interpreter object taking: 
    - ressource_manager 
    - text_converter
    '''
    interpreter = PDFPageInterpreter(resource_manager, text_converter)
    
    '''
    We are going to process the content of each page of the original PDF File
    '''
    for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password="", caching=True, check_extractable=True):
        interpreter.process_page(page)

        '''
        Retrieve the entire contents of the “file” at any time 
        before the StringIO object’s close() method is called.
        '''
        text = out_text.getvalue()

        '''
        Closing all the ressources we previously opened
        '''
        fp.close()
        text_converter.close()
        out_text.close()

        '''
        Return the final variable containing all the text of the PDF
        '''
        return text

# %%
print (get_pdf_file_content(path_to_pdf))
# Out:
#
# Abhinav Saxena
#
# Contact Information:
# M: +919818600830
# E: abhinavsaxenaesade@gmail.com
# E: abhinav.saxena@alumni.esade.edu
#
#  : Abhinav Saxena
#
#
#
#   Education
#
# ESADE Business School, Universitat Ramon Llull
# Master of Science in Management – 7.8/10
#
# McDonough School of Business, Georgetown University
# Study Abroad Program in Public Affairs & International Political Economy – 8.5/10
#
# Maharashtra Institute of Technology, University of Pune
# Bachelor of Engineering (Mechanical) – First Class with Distinction
#
#
#   Work Experience
#
# Cians Analytics – Investment Research & Analytics
# Senior Analyst II – Investment Banking
#
#
# 
#
# Preparing  and  analyzing  industry  overviews  for  various  sectors  and  markets  to  access
# investment avenues for global Investment Banks and PE firms
#
#   Developing research projects that include market sizing, value chain analysis, valuation
# ...

# %% [markdown]
# # Code For Extracting The File Name

# %%
import os
path = [r"C:\Users\shubh\OneDrive\Documents\Assignment\abhinavsaxenaesade.gmail@naukri.comabhinavsaxenaesade@gmailDotcom",r"C:\Users\shubh\OneDrive\Documents\Assignment\Abhishek Pareek",r"C:\Users\shubh\OneDrive\Documents\Assignment\amayakak3.gmail@naukri.comamayakak3@gmailDotcom",r"C:\Users\shubh\OneDrive\Documents\Assignment\ankurshgl.gmail@naukri.comCV__AnkurSehgal",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\Anvesh Dhagat",r"C:\Users\shubh\OneDrive\Documents\Assignment\bishal.agarwala02.gmail@naukri.combishalDotagarwala02@gmailDotcom",
       r"C:\Users\shubh\OneDrive\Documents\Assignment
gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\Abhishek Pareek.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\amayakak3.gmail@naukri.comamayakak3@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\ankurshgl.gmail@naukri.comCV__AnkurSehgal.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\Anvesh Dhagat.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\bishal.agarwala02.gmail@naukri.combishalDotagarwala02@gmailDotcom.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\bishta.deepak.gmail@naukri.combishtaDotdeepak@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\ca.archiegupta.gmail@naukri.comcaDotarchiegupta@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\chaturvedi.vaishali.58.gmail@naukri.comchaturvediDotvaishaliDot58@gmailDotcom.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\chaturvedi.vaishali.58.gmail@naukri.comchaturvediDotvaishaliDot58@gmailDotcom.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\dikshagarg010.gmail@naukri.comdikshagarg010@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\DINESHKUMAR.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\duttdeepak67.gmail@naukri.comduttdeepak67@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\GarimaRani.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\gauravkhurana.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\Gurleen Kaur.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\HarshitAiri.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\harshnahar24.gmail@naukri.comharshnahar24@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\Karishma Trehan.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\KusumPotai.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\manas3490.gmail@naukri.commanas3490@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\me.vivekvijayvargia@naukri.comme@vivekvijayvargiaDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\parth.Diwan94.gmail@naukri.comparthDotDiwan94@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\RajeevChaudhary.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\rishabh1500.gmail@naukri.comrishabh1500@gmailDotcom.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\RituSharma.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\SahilPopli.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\samarpanjain12@gmail.comSamarpan Jain-Resume.pdf",
       r"C:\Users\shubh\OneDrive\Documents\Assignment\SharjeelAhsan.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\SubhashKumarSah.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\TruptiRaut.pdf",r"C:\Users\shubh\OneDrive\Documents\Assignment\Tushant.pdf"]

# %%
import en_core_web_sm
import spacy
import pdfplumber
nlp = en_core_web_sm.load()

nlp = spacy.load("en_core_web_sm")
for name in lst:
    pdf = pdfplumber.open(name)
    page = pdf.pages[0]
    doc = nlp(page.extract_text())
    print([(X.text, X.label_) for X in doc.ents if X.label_ == 'PERSON'])
# Out:
# [('Abhinav Saxena', 'PERSON'), ('Abhinav Saxena \n \n \n \n  ', 'PERSON'), ('Universitat Ramon Llull', 'PERSON'), ('Screening', 'PERSON'), ('Quikr', 'PERSON'), ('Tech Startup', 'PERSON'), ('Due Diligence', 'PERSON'), ('Critical Thinking', 'PERSON')]
# [('Abhishek Pareek', 'PERSON'), ('Buy', 'PERSON'), ('Fintech Startup', 'PERSON'), ('Jyotibha Phule Rohilkhand\nAnalysis', 'PERSON'), ('Ratio Analysis', 'PERSON')]
# [('Kendriya Vidyalaya', 'PERSON'), ('Rohini  86%', 'PERSON'), ('Kendriya Vidyalaya', 'PERSON'), ('Rohini  ', 'PERSON'), ('Ansys', 'PERSON'), ('Bhedam', 'PERSON')]
# []
# [('Outline', 'PERSON'), ('Bloomberg', 'PERSON'), ('Key Deliverables', 'PERSON')]
# [('Kolkata       CGPA', 'PERSON'), ('Sarada Vidya', 'PERSON'), ('London Campus', 'PERSON'), ('IIM Kozhikode', 'PERSON'), ('L’Attitude 2018', 'PERSON')]
# [('Deepak Bisht', 'PERSON'), ('McCraken', 'PERSON'), ('Bronze Award', 'PERSON')]
# [('Gupta\xa0    V   10/4', 'PERSON')]
# ...
